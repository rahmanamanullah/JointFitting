# %% [markdown]
# # Testing

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1D models
# ## Fitting model to single data set
# Example showing how a model from a astropy.modeling can be fitted to a single data set.

# %%
# %aimport cost
# %aimport fitting
# %autoreload 2
import numpy as np
from astropy.modeling import models

# some fake data
m,k = 3.,5.
x1 = np.arange(10)
y1 = k*x1 + m
y1 += np.random.randn(len(x1))

# linear model from astropy.modeling
l1 = models.Linear1D()

# fitter
jf = fitting.JointMinuitFitter(verbose=True)
fitl = jf(l1,x1,y1)

# plot data and best fit
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x1,y1,'ko')
xx = np.linspace(x1.min(),x1.max(),300)
ax.plot(xx,fitl(xx),'r-')
ax.set_xlabel('x'); ax.set_ylabel('y')
plt.show();
plt.close();
# Out:
# Initial parameters:
# slope 1.0 step= 0.1
# intercept 0.0 step= 0.1
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 11.7408241408</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 32</td>
#                 <td title="Number of call in last migrad">NCALLS = 32</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 1.35790977339e-21</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 1.0</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#nqFfKMrBus').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>slope</td>
#                 <td>5.21635</td>
#                 <td>0.110096</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>intercept</td>
#                 <td>2.14101</td>
#                 <td>0.587754</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="nqFfKMrBus" style="display:none;">
#             <textarea rows="10" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & slope & 5.216e+00 & 1.101e-01 &  &  &  &  & \\
# \hline
# 2 & intercept & 2.141e+00 & 5.878e-01 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>

# %% [markdown]
# ## Fitting model to two data sets
# Fitting the same model to two data sets with the same slope but with different intercepts.

# %%
# %aimport fitting

common_names = ['slope']
y2  = k*x1 + 5*m
y2 += np.random.randn(len(x1))

# data
xx = np.vstack((x1,x1))
yy = np.vstack((y1,y2))

# second model
l2 = models.Linear1D()

# fitter
jf = fitting.JointMinuitFitter(verbose=False)

fitl = jf([l1,l2],xx,yy,common_names=common_names)

xxx = np.linspace(x1.min(),x1.max(),300)
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122,sharey=ax1)
ax1.plot(x1,y1,'ko')
ax1.plot(xxx,fitl[0](xxx),'r-')
ax2.plot(x1,y2,'ko')
plt.plot(xxx,fitl[1](xxx),'b-')
plt.show()
plt.close()

# %% [markdown]
# # 2D fit single model two images
# Fit two 2D Gaussians with the same sigma, but different positions and fluxes.

# %%
# %aimport fitting
from astropy.modeling import models
import matplotlib.pyplot as plt

nx,ny = 128,128

common_names = ['x_stddev','y_stddev','theta']

# Generate fake data
np.random.seed(0)
y, x = np.mgrid[:nx, :ny]

z1,z2 = x*0.0,x*0.0

z1 += np.random.randn(nx,ny)
z2 += np.random.randn(nx,ny)

# models
g1 = models.Gaussian2D(amplitude=5.,x_mean=40,y_mean=40,x_stddev=5,y_stddev=5)
g2 = models.Gaussian2D(amplitude=3.,x_mean=100,y_mean=100,x_stddev=5,y_stddev=5)

z1 += g1(x,y)
z2 += g2(x,y)

# fitter
jf = fitting.JointMinuitFitter(verbose=True)

xx = np.stack((x,x),axis=0)
yy = np.stack((y,y),axis=0)
zz = np.stack((z1,z2),axis=0)

fitl = jf([g1,g2],xx,yy,zz,maxiter=50000,common_names=common_names)

vmin,vmax = -0.1,5
fig = plt.figure(figsize=(12,7))
for n in range(2):
    axd = fig.add_subplot(2,3,n*3+1)
    axm = fig.add_subplot(2,3,n*3+2)
    axr = fig.add_subplot(2,3,n*3+3)
    z = zz[n,:]
    axd.imshow(z,origin='lower',interpolation='nearest',vmin=vmin,vmax=vmax)
    m = fitl[n](x,y)
    axm.imshow(m,origin='lower',interpolation='nearest',vmin=vmin,vmax=vmax)
    axr.imshow(z-m,origin='lower',interpolation='nearest')
plt.show()
plt.close()
# Out:
# Initial parameters:
# amplitude_0 5.0 step= 0.5
# x_mean_0 40.0 step= 4.0
# y_mean_0 40.0 step= 4.0
# x_stddev 5.0 step= 0.5
# y_stddev 5.0 step= 0.5
# theta 0.0 step= 0.1
# amplitude_1 3.0 step= 0.3
# x_mean_1 100.0 step= 10.0
# y_mean_1 100.0 step= 10.0
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 32412.053043</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 295</td>
#                 <td title="Number of call in last migrad">NCALLS = 295</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 1.84340719165e-06</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 1.0</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#XorSxFCXww').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>amplitude_0</td>
#                 <td>5.07983</td>
#                 <td>0.150445</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>x_mean_0</td>
#                 <td>39.974</td>
#                 <td>0.161922</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>y_mean_0</td>
#                 <td>39.9779</td>
#                 <td>0.15493</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>amplitude_1</td>
#                 <td>2.91034</td>
#                 <td>0.129046</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>x_mean_1</td>
#                 <td>100.168</td>
#                 <td>0.266586</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>y_mean_1</td>
#                 <td>100.25</td>
#                 <td>0.271242</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>7</td>
#                 <td>x_stddev</td>
#                 <td>5.02513</td>
#                 <td>0.137132</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>8</td>
#                 <td>y_stddev</td>
#                 <td>4.82269</td>
#                 <td>0.132681</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>9</td>
#                 <td>theta</td>
#                 <td>-0.404121</td>
#                 <td>0.476856</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="XorSxFCXww" style="display:none;">
#             <textarea rows="24" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $amplitude_{0}$ & 5.080e+00 & 1.504e-01 &  &  &  &  & \\
# \hline
# 2 & x $mean_{0}$ & 3.997e+01 & 1.619e-01 &  &  &  &  & \\
# \hline
# 3 & y $mean_{0}$ & 3.998e+01 & 1.549e-01 &  &  &  &  & \\
# \hline
# 4 & $amplitude_{1}$ & 2.910e+00 & 1.290e-01 &  &  &  &  & \\
# \hline
# 5 & x $mean_{1}$ & 1.002e+02 & 2.666e-01 &  &  &  &  & \\
# \hline
# 6 & y $mean_{1}$ & 1.002e+02 & 2.712e-01 &  &  &  &  & \\
# \hline
# 7 & $x_{stddev}$ & 5.025e+00 & 1.371e-01 &  &  &  &  & \\
# \hline
# 8 & $y_{stddev}$ & 4.823e+00 & 1.327e-01 &  &  &  &  & \\
# \hline
# 9 & $\theta$ & -4.041e-01 & 4.769e-01 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>

# %% [markdown]
# # The cost function with custom defined functions
# The procudure below can be implemented directly in iminuit, which would be more straight-forward than what is done here.  The intention here is rather to show how this class can be used with custom functions.
#
# The const function is implemented as general class, JointCostFunctor, following the example from <a href='http://nbviewer.jupyter.org/github/iminuit/iminuit/blob/master/tutorial/tutorial.ipynb'>the iminuit tutorial</a>.

# %%
# %aimport cost
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
from iminuit import Minuit

def linear(x,m,c) :
    """
    Linear hypothesis
    """
    return m*x + c

def parabola(x,a,b,c):
    """
    Parabolic hypothesis
    """
    return a*x**2 + b*x + c

# data
x = np.array([1,2,3,4,5])
y = 3 + x*3 + x*x*5

# plot data
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y,'ko')

# setup minuit function
test1 = cost.JointCostFunctor(linear,x,y)
print describe(test1)
test2 = cost.JointCostFunctor(parabola,x,y)
print describe(test2)

# setup minuit object and minimize
m = Minuit(test1)
m.migrad()
print(m.values)

# plot fits
xx = np.linspace(x.min(),x.max(),300)
ax.plot(xx,linear(xx,m.values['m'],m.values['c']),'r-')

m = Minuit(test2)
m.migrad()
print(m.values)

ax.plot(xx,parabola(xx,m.values['a'],m.values['b'],m.values['c']),'b-')
ax.set_xlabel('x')
ax.set_ylabel('y')

plt.show()
plt.close()
# Out:
# ['m', 'c']
# ['m', 'c']
# ['a', 'b', 'c']
# ['a', 'b', 'c']
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 350.0</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 32</td>
#                 <td title="Number of call in last migrad">NCALLS = 32</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 1.77105551473e-20</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 1.0</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#WuuVCVAvGR').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>m</td>
#                 <td>33</td>
#                 <td>0.316228</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>c</td>
#                 <td>-32</td>
#                 <td>1.04881</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="WuuVCVAvGR" style="display:none;">
#             <textarea rows="10" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & m & 3.300e+01 & 3.162e-01 &  &  &  &  & \\
# \hline
# 2 & c & -3.200e+01 & 1.049e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# {'c': -32.00000000001421, 'm': 32.999999999995005}
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 3.43182107903e-18</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 59</td>
#                 <td title="Number of call in last migrad">NCALLS = 59</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 3.43188185273e-18</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 1.0</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#ESWYUzYNlo').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>a</td>
#                 <td>5</td>
#                 <td>0.267261</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>b</td>
#                 <td>3</td>
#                 <td>1.63445</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>c</td>
#                 <td>3</td>
#                 <td>2.14476</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="ESWYUzYNlo" style="display:none;">
#             <textarea rows="12" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & a & 5.000e+00 & 2.673e-01 &  &  &  &  & \\
# \hline
# 2 & b & 3.000e+00 & 1.634e+00 &  &  &  &  & \\
# \hline
# 3 & c & 3.000e+00 & 2.145e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# {'a': 5.000000000046059, 'c': 2.9999999997949764, 'b': 3.0000000001067813}

# %% [markdown]
# ## astropy.modeling
# Same example as above but instead of manually defining functions we use models from astropy.modeling.

# %%
from astropy.modeling import models

l = models.Linear1D()
p = models.Polynomial1D(2,{'a':0,'b':0,'c':0})
p.prepare_inputs(x)

# plot data
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y,'ko')

# setup minuit function
test1 = cost.JointCostFunctor(l.evaluate,x,y)
print describe(test1)

## I have not managed to figure out how to set the
## function signature for iminuit for models that
## set their parameter list dynamically
test2 = minuit.JointCostFunctor(p.evaluate,x,y,param_names=['c0','c1','c2'])
print describe(test2)

# setup minuit object and minimize
m1 = Minuit(test1)
m1.migrad()
print(m1.values)

# plot fits
for k in l.param_names:
    l.parameters[l.param_names.index(k)] = m1.values[k]
ax.plot(xx,l(xx),'r-')

m2 = Minuit(test2,c0=0.0,c1=0.0,c2=0.0)
#m2.migrad()
#print(m2.values)
# plot fits
#for k in p.param_names:
#    p.parameters[p.param_names.index(k)] = m2.values[k]
#ax.plot(xx,p(xx),'r-')

ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()
plt.close()
# Out:
# ['slope', 'intercept']
# ['slope', 'intercept']
# ['c0', 'c1', 'c2']
# ['c0', 'c1', 'c2']
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 350.0</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 32</td>
#                 <td title="Number of call in last migrad">NCALLS = 32</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 1.77105551473e-20</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 1.0</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#cTWbsjjCxj').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>slope</td>
#                 <td>33</td>
#                 <td>0.316228</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>intercept</td>
#                 <td>-32</td>
#                 <td>1.04881</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="cTWbsjjCxj" style="display:none;">
#             <textarea rows="10" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & slope & 3.300e+01 & 3.162e-01 &  &  &  &  & \\
# \hline
# 2 & intercept & -3.200e+01 & 1.049e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# {'slope': 32.999999999995005, 'intercept': -32.00000000001421}
